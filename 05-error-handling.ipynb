# %% [markdown]
# <h1 style='font-size:40px'>
#     REST API Error Handling Patterns
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> REST API Error Handling Practices
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Nessa aula, aprendemos algumas boas práticas envolvendo o retorno de mensagens de erro em API's.
#         </li>
#         <li>
#             De maneira geral, costuma-se informar o status-code e reason-phrase padrão. Caso deseje, você pode acrescentar mais alguma informação num header customizado de prefixo "x-", ou body.
#         </li>
#         <li>
#             Por questões de manutenibilidade, recomenda-se usar uma quantidade limitada de status codes, em torno de 10. Foque nos códigos mais comuns (200, 201, 404...).
#         </li>
#     </ul>
# </div>

# %%
! git add .
! git commit -am 'Aula 30'
! git push
# Out:
# [master 4ffcf7a] iniciar seção 5
#  4 files changed, 172 insertions(+), 92 deletions(-)
#  create mode 100644 .ipynb_checkpoints/05-error-handling-checkpoint.ipynb
#  create mode 100644 05-error-handling.ipynb
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 872 bytes | 872.00 KiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 3 local objects.
# To https://github.com/felipesveiga/api.git
#    94fca60..4ffcf7a  master -> master

# %% [markdown]
# <p style='color:red'> Vi Aula 29; Aula 30
