# %% [markdown]
# <h1 style='font-size:40px'>
#     API Management
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Esta seção é volta para o ensinamento de boas práticas no desenvolvimento de API's.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> API Lifecycle & Developer Productivity
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             De maneira geral, podemos separar o ciclo de vida de uma API em quatro partes.
#             <ul>
#                 <li>
#                     <i> Build:</i> Montagem da API, ou de uma nova versão.
#                 </li>
#                 <li>
#                     <i> Publish:</i> Publicação da versão da API.
#                 </li>
#                 <li>
#                     <i> Deprecated:</i> Categorização da versão como defasada, permitindo o seu uso apenas para os usuários que já tinham acesso a ela, até uma data acordada.
#                 </li>
#                 <li>
#                     <i> Retired:</i> Remoção da versão dos servidores.
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             <img src='img/11-lifecycle.png'>
#             <figcaption style='font-size:15px'>
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Developer Portal</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Quando pensamos na Experiência de Usuário, é fundamental conseguirmos providenciar 3 recursos para nossos clientes:
#             <ul>
#                 <li>
#                     <i> Documentação:</i> Tanto OAI, quanto de usuário.
#                 </li>
#                 <li>
#                     <i> Serviço de Acesso:</i> Canal de solicitação de acesso para a API.
#                 </li>
#                 <li>
#                     <i> Suporte:</i> Serviço de auxílio aos desenvolvedores com a API.
#                 </li>
#             </ul>
#         </li>
#         <li>
#             Todas essas funcionalidades podem ser disponibilizadas num <i> Developer Portal</i>. Conseguimos tanto desenvolver um portal interno, quanto comprar um vendido por empresas de TI.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Melhores Práticas</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#         </li>
#      </ul>
# </div>

# %% [markdown]
# <h5 style='font-size:25px;font-style:italic;text-decoration:underline'> Documentação</h5>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Ao criar a documentação do Developer Portal, busque tornar o usuário mais o familiarizado possível com o funcionamento da API.
#         </li>
#         <li>
#             Para isso, recomenda-se incluir features "Try It", em que ele possa interagir com a API por uma interface gráfica, ou providenciar códigos de exemplo sobre como uma requisição típica deveria ser escrita.
#         </li>
#         <li>
#             Se possível, ainda podemos criar uma SDK que torne a interação com a API ainda mais abstraída!
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h5 style='font-size:25px;font-style:italic;text-decoration:underline'> Serviço de Acesso</h5>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A forma como o usuário deverá pedir acesso à sua API dependerá de suas características. Para aquelas de conjunto de clientes menor, talvez um fluxo manual e informal de pedido seja o suficiente.
#         </li>
#         <li>
#             Agora, quando pensamos em API's para públicos mais amplos, é interessante incluirmos automações e algumas burocracias a fim de garantir que apenas as pessoas necessárias tenham acesso ao endpoint.
#         </li>
#         <li>
#             É crucial se definir a pessoa responsável por gerenciar o permissionamento de acessos à API.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             <img src='img/11-automatic-approval.png'>
#             <figcaption style='font-size:15px'>
#                 Esquematização de solicitação de acesso automático. Para API's mais simples, podemos conceder a aprovação automaticamente, enquanto que para as mais sensíveis, é importante designarmos as solicitações para o responsável por elas.
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h5 style='font-size:25px;font-style:italic;text-decoration:underline'> Support</h5>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Quando trata-se de suporte à sua API, tudo dependerá da escala que ela adquirir.
#         </li>
#         <li>
#             No nível mais básico, é importante existir um portal onde os clientes possam abrir chamados para correções. Também é interessante fornecermos uma FAQ e um guia de boas práticas para sanar dúvidas recorrentes.
#         </li>
#         <li>
#             Conforme a API ganhar mais público, pode ser interessante criar fóruns onde o time da API e seus clientes possam se ajudar com problemas de forma mais fluida.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> API Security Management
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Tratando-se do gerenciamento de API's, considera-se como requisito mínimo a identificação dos consumidores (seja por chave, por exemplo).
#         </li>
#         <li>
#             Ao conseguirmos associar uma requisição a um cliente, podemos detectar possíveis ofensores à nossa API, facilitando os meios de anulação de ataques (como cancelamento da chave).
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Functional Threats</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             É importante também sempre nos preocuparmos com a segurança de nossa API. Durante seu desenvolvimento, devemos elaborar testes que garantam a sua proteção a possíveis ataques.
#         </li>
#         <li>
#             Seria interessante haver um time de desenvolvedores que tentem proativamente encontrar vulnerabilidades de segurança, reportando a você quando houver.
#         </li>
#         <li>
#             Se possível, elabore uma monitoração focada em segurança da API.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> API Traffic Management
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Nessa aula, aprendemos sobre melhores práticas no gerenciamento de tráfego sobre API's.
#         </li>
#         <li>
#             Devemos garatir que o desempenho da API sempre esteja conforme as especificações do seu SLA. Isso depende tanto da qualidade da sua infraestrutura, quanto do gerenciamento do consumo dos seus clientes.
#         </li>
#     </ul>
# </div>

# %%
! git add .
! git commit -am 'Citar boas práticas no gerenciamento de tráfego da API'
! git push
# Out:
# [master 08ab76d] Citar boas pr´áticas no gerenciamento de tráfego da API
#  2 files changed, 52 insertions(+), 14 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 827 bytes | 827.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/felipesveiga/api.git
#    73f41c5..08ab76d  master -> master

# %% [markdown]
# <p style='color:red'> Iniciei Aula 57; Citar boas práticas no gerenciamento de tráfego da API
