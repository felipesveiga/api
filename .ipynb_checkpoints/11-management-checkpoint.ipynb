# %% [markdown]
# <h1 style='font-size:40px'>
#     API Management
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#         </li>
#     </ul>
# </div>

# %%
! git add .
! git commit -am 'Iniciar seção 11'
! git push
# Out:
# [master 9314390] Aula 66 (5:25)
#  2 files changed, 126 insertions(+), 82 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.03 KiB | 1.03 MiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/felipesveiga/api.git
#    3bedd3d..9314390  master -> master

# %% [markdown]
# <p style='color:red'> Terminei seção 10; Iniciar seção 11
