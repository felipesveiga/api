# %% [markdown]
# <h1 style='font-size:40px'>
#     REST API Security
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#         </li>
#     </ul>
# </div>

# %%
! git add .
! git commit -am 'Iniciar seção 9'
! git push
# Out:
# [master fa7530f] Aula 41
#  4 files changed, 96 insertions(+), 30 deletions(-)
#  create mode 100644 img/08-cursor-response.png
#  create mode 100644 img/08-get-cursor.png
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 33.95 KiB | 33.95 MiB/s, done.
# Total 7 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/felipesveiga/api.git
#    bc34640..fa7530f  master -> master

# %% [markdown]
# <p style='color:red'> Finalizei seção 8; Iniciar seção 9
