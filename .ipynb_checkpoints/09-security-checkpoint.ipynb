# %% [markdown]
# <h1 style='font-size:40px'>
#     REST API Security
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Por se tratar de uma interface de transferência de dados, as API's REST devem ter mecanismos robustos para garantir a proteção dessas informações de acessos indevidos ou interceptações.
#         </li>
#         <li>
#             Nessa seção, vamos estudar as formas mais comuns de implementá-los, desde as mais simples às mais modernas.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             <img src='img/09-attack-possibilities.png'>
#             <figcaption style='font-size:15px'>
#                 Um potencial atacante pode atuar em qualquer componente da arquitetura de uma API REST.
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h2 style='font-size:30px'> Securing API with Basic Authentication
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Nessa aula, aprendemos sobre a Basic Authentication. Ela é a forma mais primordial de autenticação em API's.
#         </li>
#         <li>
#             Ela consiste na passagem das credenciais de usuário no header Authorization. Elas seguem o formato de &lt;userame&gt;:&lt;password&gt; em Base64.
#         </li>
#         <li>
#             No entanto, essa metodologia de autenticação é vulnerável a interceptações a ataques <i> man in the middle</i>, pelas credenciais não serem encriptadas. As chances desse tipo de ataque aumentam, principalmente pelo fato de o usuário ter que informar esses dados a cada requisição, em conformidade com o caráter stateless do REST.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             <img src='img/09-basic-auth.png'>
#             <figcaption style='font-size:15px'>
#                 Esquematização de uma requisição em Basic Auth.
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h2 style='font-size:30px'> Securing API with Tokens & JWT
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Uma outra maneira de autenticarmos o nosso acesso a uma aplicação seria com os JSON Web Tokens (JWT).
#         </li>
#         <li>
#             Esses tokens seriam passes temporários e com permissões definidas concedidos pelo sistema. De forma geral, o usuário deverá informar suas credenciais a um servidor de autenticação, que retornaria o JWT, em caso de sucesso.
#         </li>
#         <li>
#             Assim, o usuário deverá informar esse token no header `Authetication` nas próximas interações para interagir com a aplicação.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             <img src='img/09-jwt-flow.png'>
#             <figcaption style='font-size:15px'>
#                 Esquematização geral do fluxo de autenticação JWT.
#             </figcaption>
#         </figure>
#     </center>

# %%
! git add .
! git commit -am 'Explicar estrutura do JSON Web Token'
! git push
# Out:
# [master 62d3714] Explicar funcionamento da autenticação JWT
#  2 files changed, 14 insertions(+), 14 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 573 bytes | 573.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/felipesveiga/api.git
#    81438dc..62d3714  master -> master

# %% [markdown]
# <p style='color:red'> Expliquei funcionamento da autenticação JWT; Explicar estrutura do JSON Web Token; Fazer anotações Aula 44 com base no <a href='https://developer.auth0.com/resources/labs/tools/jwt-basics#introduction'>artigo Auth0 </a>;
# "
