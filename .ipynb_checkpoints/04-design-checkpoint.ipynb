# %% [markdown]
# <h1 style='font-size:40px'>
#     Desigining REST API
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Nessa seção, aprendemos os principais conceitos voltados à criação de API's.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> API Endpoint URL
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             As URL's de API's cosutmam seguir um padrão em sua estrutura que torna mais compreensível a organização e hierarquia de recursos.
#         </li>
#         <li>
#             Nessa aula, vamos definir cada um dos seus componentes.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#             <img src='img/04-url-structure.png'>
#         <figcaption style='font-size:15px'>
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Componentes da URL</h3>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Domain</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Consiste no nome do domínio em que a(s) API'(s) estão disponibilizadas.
#         </li>
#         <li>
#             No caso, ele seria usado para obter o endereço de IP do servidor que as hospeda.
#         </li>
#         <li>
#             Muitas empresas preferem hospedar suas API's num domínio diferente de seu site oficial, com o uso de sub-domínios, por exemplo (paypal.com$\to$api.paypal.com).
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Product [Optional]</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Consiste numa camada de abstração em que agrupamos diversos recursos, com base em características em comum.
#         </li>
#         <li>
#             Em empresas grandes, o campo de product pode ser usado para apartar diferentes API's sob responsabilidades de times distintos.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Version [Optional]</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Consiste na versão de sua API. Dar a opção ao cliente de escolhê-la impede de expô-lo a possíveis erros de atualizações.
#         </li>
#         <li>
#             No entanto, esse identificador não precisa estar no caminho, uma vez que ele pode ser especificado como um metadado na requisição do cliente, também.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Resource</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Finalmente, o recurso um tipo de entidade hospedado pela API com a qual conseguimos interagir.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> Practices for Resource Names, Actions & Associations
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Nessa aula, aprendemos algumas boas-práticas nas nomenclaturas de URL's de API's.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Resource Name</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Recomenda-se usarmos substantivos como nomes de entidades tidas pela API. Além disso, costuma-se usá-los no plural.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Resource Association</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A rota de um determinado recurso pode ser usada para encapsular outras entidades relacionadas a ele.
#         </li>
#         <li>
#             Nessa situação, esses sub-recursos podem ser interpretados como atributos da entidade raiz (similar ao que temos em OOP).
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#             <img src='img/04-nested-resources.png'>
#         <figcaption style='font-size:15px'>
#             Exemplo de anihamento de recursos numa API de previsão do tempo.
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Action Hosting</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Podemos fazer com que a API hospede não apenas entidades, mas também ações que podem ser realizadas no backend. Neste caso, recomenda-se definir o nome do recurso como um verbo.
#         </li>
#         <li>
#             O exemplo mais notório é o da API do Google, em que todas as buscas são feitas no recurso "search".
#         </li>
#         <li>
#             É indicado habilitarmos rotas de ação quando uma entidade puder se consultada usando diferentes parâmetros. Por exemplo, numa API do LinkedIn, poderíamos buscar por pessoas por nome, localização ou empresa atual (search?name=&lt;name&gt;&location=&lt;location&gt;&employer=&lt;employer&gt;).
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> HTTP API Request flow and HTTP Status Code
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Nessa aula, somos apresentados a noções gerais a respeito de contratos de API.
#         </li>
#         <li>
#             Em API's REST, podemos especificar os parâmetros de consulta e resposta para as operações de cada recurso.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#             <img src='img/04-uniform-interface.png'>
#         <figcaption style='font-size:15px'>
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> Status Codes</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Os status codes são componentes essenciais nas respostas de qualquer API. Eles informam o cliente sobre a situação de sua requisição.
#         </li>
#         <li>
#             Normalmente, são declarados no header das respostas.
#         </li>
#         <li>
#             Esses códigos seguem um padrão numérico cujo significado é especificado abaixo. Para mais informações sobre cada um deles, você pode conferir a <a href='https://www.w3.org/Protocols/rfc2616/rfc2616-sec6.html#sec6.1.1'>RFC2616</a>.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <table style='font-size:15px'>
#     <tr>
#         <th>
#              Status Code
#         </th>
#         <th>
#             Meaning
#         </th>
#     </tr>
#     <tr>
#         <td>
#             1xx
#         </td>
#         <td>
#             Informational
#         </td>
#     </tr>
#     <tr>
#         <td>
#             2xx
#         </td>
#         <td>
#             Success
#         </td>
#     </tr>
#     <tr>
#         <td>
#             3xx
#         </td>
#         <td>
#             Redirection
#         </td>
#     </tr>
#     <tr>
#         <td>
#             4xx
#         </td>
#         <td>
#             Client Error
#         </td>
#     </tr>
#     <tr>
#         <td>
#             5xx
#         </td>
#         <td>
#             Server Error
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <h2 style='font-size:30px'> Implementing REST API CRUD operations
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Um dos fatores essenciais para a sustentabilidade de uma API seria a disponibilização de métodos que suportem o tratamento completo dos recursos.
#         </li>
#         <li>
#             No caso, o usuário deveria ter liberdade de tanto criar, atualizar, resgatar ou deletar qualquer representação de recurso hospedado no backend da API. Essas ações essenciais são conhecidas como <strong>CRUD Operations</strong>.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <figure>
#     <center>
#         <table style='font-size:15px'>
#             <tr>
#                 <th>
#                      Operation
#                 </th>
#                 <th>
#                     HTTP Method
#                 </th>
#             </tr>
#             <tr>
#                 <td>
#                     Create
#                 </td>
#                 <td>
#                     POST
#                 </td>
#             </tr>
#             <tr>
#                 <td>
#                     Retrieve
#                 </td>
#                 <td>
#                     GET
#                 </td>
#             </tr>
#             <tr>
#                 <td>
#                     Update
#                 </td>
#                 <td>
#                     PUT, PATCH
#                 </td>
#             </tr>
#             <tr>
#                 <td>
#                     Delete
#                 </td>
#                 <td>
#                     DELETE
#                 </td>
#             </tr>
#         </table>
#         <figcaption style='font-size:15px'> Cada uma das operações CRUD pode ser executada em um método HTTP específico.</figcaption>
#     </center>
# </figure>

# %% [markdown]
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Abaixo, vamos dar uma visão geral do que normalmente é esperado nos dados de entrada e saída de uma requisição em API's.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'>  POST</h3>

# %% [markdown]
# <figure>
#     <center>
#         <table style='font-size:15px;text-align:center'>
#             <thread>
#                 <tr>
#                     <th></th>
#                     <th>
#                          Request
#                     </th>
#                     <th>
#                         Response
#                     </th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <tr>
#                     <td>
#                         <strong>URL</strong>
#                     </td>
#                     <td>
#                         Path do recurso a ser interagido
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         <strong>Header</strong>
#                     </td>
#                     <td>
#                         Optional
#                     </td>
#                     <td>
#                         Status Code: 201, 400, 5xx
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         <strong>Body</strong>
#                     </td>
#                     <td>
#                         <p>Atributos da instância</p>
#                     </td>
#                     <td>
#                         <p>JSON com a representação da instância</p>
#                         <p>HATEOAS com o caminho da instância na API</p>
#                     </td>
#                 </tr>
#             </tbody>
#         </table>
#         <figcaption style='font-size:15px'></figcaption>
#     </center>
# </figure>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'>  GET</h3>

# %% [markdown]
# <figure>
#     <center>
#         <table>
# <thead>
# <tr>
# <th>
# </th>
# <th>
# Request
# </th>
# <th>
# Response
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <strong> URL</strong>
# </td>
# <td>
# <p>Path do recurso ou entidade a ser resgatado
# </p>
# <p>
# Path com uma query a ser feita no recurso
# </p>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# <strong> Header</strong>
# </td>
# <td>
# </td>
# <td>
# Status Code: 200, 404, 5xx
# </td>
# </tr>
# <tr>
# <td>
# <strong>
# Body
# </strong>
# </td>
# <td>
# </td>
# <td>
# <p> Dados da instância requisitada</p>
# <p> Coleção de dados das instâncias que correspondem à query</p>
# </td>
# </tr>
# </tbdody>
# </table>
#         <figcaption style='font-size:15px'></figcaption>
#     </center>
# </figure>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> PUT, PATCH</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Ao contrário das demais operações CRUD, o UPDATE de um recurso pode ocorrer por meio de um PUT ou PATCH.
#         </li>
#         <li>
#             PUT's são usados para atualização completa de uma representação, enquanto que PATCH's para alteração de apenas alguns atributos.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <figure>
#     <center>
#         <table style='font-size:15px;text-align:center'>
#             <thread>
#                 <tr>
#                     <th></th>
#                     <th>
#                          Request
#                     </th>
#                     <th>
#                         Response
#                     </th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <tr>
#                     <td>
#                         <strong>URL</strong>
#                     </td>
#                     <td>
#                         <p>
#                             Path da representação
#                         </p>
#                         <p>
#                             Path com query para recursos a serem alterados
#                         </p>
#                         <p>
#                             Optional: O caminho passado já pode conter os novos valores dos atributos a serem modificados
#                         </p>
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         <strong>Header</strong>
#                     </td>
#                     <td>
#                         Optional
#                     </td>
#                     <td>
#                         Status Code: 200, 201, 204, 4xx, 5xx
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         <strong>Body</strong>
#                     </td>
#                     <td>
#                         <p>Optional: Novos valores dos atributos a serem atualizados</p>
#                     </td>
#                     <td>
#                         O conteúdo dependerá do status code dado pela API
#                     </td>
#                 </tr>
#             </tbody>
#         </table>
#         <figcaption style='font-size:15px'></figcaption>
#     </center>
# </figure>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'>  DELETE</h3>

# %% [markdown]
# <figure>
#     <center>
#         <table style='font-size:15px;text-align:center'>
#             <thread>
#                 <tr>
#                     <th></th>
#                     <th>
#                          Request
#                     </th>
#                     <th>
#                         Response
#                     </th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <tr>
#                     <td>
#                         <strong>URL</strong>
#                     </td>
#                     <td>
#                         <p>
#                             Path da representação
#                         </p>
#                         <p>
#                             Path com query para recursos a serem alterados
#                         </p>
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         <strong>Header</strong>
#                     </td>
#                     <td>
#                         Optional
#                     </td>
#                     <td>
#                         Status Code: 200, 204, 4xx, 5xx
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         <strong>Body</strong>
#                     </td>
#                     <td>
#                     </td>
#                     <td>
#                         O conteúdo dependerá do status code dado pela API
#                     </td>
#                 </tr>
#             </tbody>
#         </table>
#         <figcaption style='font-size:15px'></figcaption>
#     </center>
# </figure>

# %%
! git add .
! git commit -am 'Aula 26'
! git push
# Out:
# [master 20f604a] Aula 25 (4:35)
#  2 files changed, 120 insertions(+), 138 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 865 bytes | 865.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/felipesveiga/api.git
#    97c4da1..20f604a  master -> master

# %% [markdown]
# <p style='color:red'> Defini UPDATE e DELETE; Aula 26
