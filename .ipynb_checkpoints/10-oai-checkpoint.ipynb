# %% [markdown]
# <h1 style='font-size:40px'>
#     REST API Specifications using Swagger 2.0 / OAI
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Nessa seção, lidamos com o processo de documentação de uma API.
#         </li>
#         <li>
#             Em projetos reais, é sempre bom pensarmos primeiro no contrato mais adequado para a aplicação, antes de desenvolvê-la de fato. Isso evita retrabalhos durante a criação da API.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> Requirements Analysis Process & Intro to REST Specifications
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             O contrato de uma API seria um documento que informa de maneira padronizada todas as funcionalidades disponíveis, assim como utilizá-las.
#         </li>
#         <li>
#             Apesar de existirem diversas modalidades de contrato na indústria, a Swagger acabou se consolidando como a mais popular!
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> Swagger/OAI Specifications Walkthrough
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Os contratos da especificação Swagger/Open API são documentos em YAML.
#         </li>
#         <li>
#             Apesar de podemos gerá-lo em qualquer editor de texto, recomenda-se usarmos editor.swagger.io, pois ele consegue apresentar também uma preview do documento a ser apresentado ao cliente.
#         </li>
#     </ul>
# </div>

# %% [markdown]
#  <center style='margin-top:20px;font-size:20px'>
#         <figure>
#             <img src='img/10-swagger-editor.png'>
#             <figcaption style='font-size:15px'>
#                 Visão tida pelo Swagger Editor.
#             </figcaption>
#         </figure>
#     </center>

# %% [markdown]
# <h2 style='font-size:30px'> Swagger/OAI Specifications
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Nessa aula, iniciamos o aprendizado sobre como escrever contratos da especificação Open API.
#         </li>
#         <li>
#             Um contrato Swagger é composto por seções pré-estabelecidas, nós passaremos por cada uma delas.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> info</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             É onde especificamos os metadados da API. Possui tanto chaves simples, quanto compostas.
#         </li>
#         <li>
#             Entre as simples, podemos mencionar:
#             <ul>
#                 <li>
#                     <i> title</i>
#                 </li>
#                 <li>
#                     <i> description</i>
#                 </li>
#                 <li>
#                     <i> version</i>
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </div>

# %%
! git add .
! git commit -am 'Definir campos de "info" da especificação OAI'
! git push
# Out:
# [master eaa0405] Fazer anotações da Aula 60
#  6 files changed, 374 insertions(+), 68 deletions(-)
#  create mode 100644 .ipynb_checkpoints/10-oai-checkpoint.ipynb
#  create mode 100644 10-oai.ipynb
#  create mode 100644 img/09-cross-site.png
#  create mode 100644 img/09-token-hijacking.png
# Enumerating objects: 12, done.
# Counting objects: 100% (12/12), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 470.52 KiB | 23.53 MiB/s, done.
# Total 8 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 4 local objects.
# To https://github.com/felipesveiga/api.git
#    d5d5041..eaa0405  master -> master

# %% [markdown]
# <p style='color:red'> Vi Aula 60; Fiz Quiz 12; Iniciei Aula 50; Definir campos de "info" da especificação OAI
