# %% [markdown]
# <h1 style='font-size:40px'>
#     REST API Cache Control Patterns
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#         </li>
#     </ul>
# </div>

# %%
! git add .
! git commit -am 'Iniciar seção 7'
! git push
# Out:
# [master 8044502] Aula 33
#  2 files changed, 140 insertions(+), 24 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.99 KiB | 1.99 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/felipesveiga/api.git
#    29a3baa..8044502  master -> master

# %% [markdown]
# <p style='color:red'> Vi Aulas 33 e 34; Iniciar seção 7
