# %% [markdown]
# <h1 style='font-size:40px'>
#     Setting the Stage
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Esse curso pretende discutir a criação de API's REST, apresentando desde os conceitos mais básicos, como padrões de design, até mais avançados, como documentações e questões de segurança.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> ACME Travels - Case study
# </h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A fim de exemplificar os conceitos estudados, vamos analisar um projeto de uma agência de turismo fictícia, a ACME.
#         </li>
#         <li>
#             Atualmente, o time da empresa tem o desafio de criar API's que simplifiquem a integração de seus sistemas, centralizando interações de clientes e vendedores num único recurso.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#             <img src='img/01-acme-tobe.png'>
#         <figcaption style='font-size:15px'>
#             Desenho lógico da arquitetura final desejada pela ACME.
#         </figcaption>
#     </center>
# </figure>

# %%
! git add .
! git commit -am 'Fazer Aula 5'
! git push
# Out:
# [master b68a779] Ver algumas aulas do curso "REST API Design, Development & Management", antes de comprar
#  4 files changed, 244 insertions(+), 14 deletions(-)
#  create mode 100644 img/15-multiple-groups.png
#  create mode 100644 img/15-multiple-origins.png
# failed to send, dropping 1 traces to intake at http://localhost:8126/v0.5/traces after 3 retries
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 152.22 KiB | 50.74 MiB/s, done.
# Total 7 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/felipesveiga/aws-developer.git
#    ec83e06..b68a779  master -> master

# %% [markdown]
# <p style='color:red'> Iniciei curso; Fazer Aula 5
