# %% [markdown]
# <h1 style='font-size:40px'>
#     REST API Handling Change - Versioning Patterns
# </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#         </li>
#     </ul>
# </div>

# %%
! git add .
! git commit -am 'Iniciar seção 6'
! git push
# Out:
# [master c76eb86] Aula 30 (5:15)
#  2 files changed, 130 insertions(+), 18 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.07 KiB | 1.07 MiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/felipesveiga/api.git
#    7e4052f..c76eb86  master -> master

# %% [markdown]
# <p style='color:red'> Terminei Aula 30; Finalizei Seção 5; Iniciar seção 6
